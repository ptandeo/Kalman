# %%
# %load_ext autoreload
# %autoreload 2

from codes.Kalman import *
from scipy.integrate import odeint

# %pylab inline
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (16, 9)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
### IMPORTANT PARAMETERS

# index of the unobserved component
i_unobs_comp = 0

# variance of the random white noise added to the unobserved component in the initial catalog
variance_unobs_comp = 5

# variance of the observations used to generate the catalog and used in the Kalman smoother
variance_obs_comp = 0.0001

# number of Lorenz-63 times
nb_loop = 10

# number of SEM iterations
nb_iter_SEM = 30

# %%
### GENERATE SIMULATED DATA

# Lorenz-63 dynamical model
def Lorenz_63(x, dx, sigma, rho, beta):
    dx = zeros((3))
    dx[0] = sigma*(x[1]-x[0])
    dx[1] = x[0]*(rho-x[2])-x[1]
    dx[2] = x[0]*x[1] - beta*x[2]
    return dx

# Lorenz-63 parameters
x0 = array([8, 0, 30]) # initial condition
dt = 0.001 # integration time step
sigma = 10; rho = 28; beta = 8/3 # physical parameters

# time and truth
t   = arange(0.01, nb_loop, dt)
x_t = odeint(Lorenz_63, x0, arange(0.01, nb_loop, dt), args=(sigma, rho, beta))

# observations
y = x_t.copy()
y = delete(y, i_unobs_comp, axis=1)
### ADD NOISE HERE? ###

# %% [markdown]
# ### V1: $x = [x_2, x_3, z_1]$

# %%
# state
z = random.normal(loc=x_t[:,i_unobs_comp]*0, scale=variance_unobs_comp, size=shape(y)[0])
x = c_[y[:,0], y[:,1], z]

# shapes
n = shape(x)[1]
p = shape(y)[1]

# colors and labels of the components
tab_colors = ['tab:blue', 'tab:orange', 'tab:green']
tab_labels = ['$x_2$', '$x_3$', '$z_1$']

# plot the components
plot(t, x)
xlabel('System loops', size=20)
ylabel('Components of the system', size=20)
legend(tab_labels, loc=1, fontsize='xx-large')
title('Initial x', size=30)
# Out:
# Text(0.5, 1.0, 'Initial x')

# %%
# kalman parameters
H = delete(eye(n), 2, axis=0)
R = variance_obs_comp*eye(p)

# stochastic EM
x_s_V1, P_s_V1, M_V1, tab_loglik_V1, x = Kalman_SEM(x, y, H, R, nb_iter_SEM)
# Out:
# 100%|██████████| 30/30 [00:47<00:00,  1.58s/it]

# %%
# plot the reconstructed components
for i in range(n):
    plot(t, x_s_V1[:,i], color=tab_colors[i])
    fill_between(t, x_s_V1[:,i]-1.96*P_s_V1[:,i,i], x_s_V1[:,i]+1.96*P_s_V1[:,i,i],
                 facecolor=tab_colors[i], alpha=0.50)

xlabel('System loops', size=20)
ylabel('Components of the system', size=20)
legend(tab_labels, loc=1, fontsize='xx-large')
title('Final x', size=30)
# Out:
# Text(0.5, 1.0, 'Final x')

# %% [markdown]
# ### V2: $x = [x_2, x_3, z_1, z_2]$

# %%
# state
z = random.normal(loc=x_t[:,i_unobs_comp]*0, scale=variance_unobs_comp, size=shape(y)[0])
x = c_[x, z]

# shapes
n = shape(x)[1]
p = shape(y)[1]

# colors and labels of the components
tab_colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']
tab_labels = ['$x_2$', '$x_3$', '$z_1$', '$z_2$']

# plot the components
plot(t, x)
xlabel('System loops', size=20)
ylabel('Components of the system', size=20)
legend(tab_labels, loc=1, fontsize='xx-large')
title('Initial x', size=30)
# Out:
# Text(0.5, 1.0, 'Initial x')

# %%
# kalman parameters
H = delete(eye(n), [2,3], axis=0)
R = variance_obs_comp*eye(p)

# stochastic EM
x_s_V2, P_s_V2, M_V2, tab_loglik_V2, x = Kalman_SEM(x, y, H, R, nb_iter_SEM)
# Out:
# 100%|██████████| 30/30 [00:48<00:00,  1.60s/it]

# %%
# plot the reconstructed components
for i in range(n):
    plot(t, x_s_V2[:,i], color=tab_colors[i])
    fill_between(t, x_s_V2[:,i]-1.96*P_s_V2[:,i,i], x_s_V2[:,i]+1.96*P_s_V2[:,i,i],
                 facecolor=tab_colors[i], alpha=0.50)

xlabel('System loops', size=20)
ylabel('Components of the system', size=20)
legend(tab_labels, loc=1, fontsize='xx-large')
title('Final x', size=30)
# Out:
# Text(0.5, 1.0, 'Final x')

# %% [markdown]
# ### V3: $x = [x_2, x_3, z_1, z_2, z_3]$

# %%
# state
z = random.normal(loc=x_t[:,i_unobs_comp]*0, scale=variance_unobs_comp, size=shape(y)[0])
x = c_[x, z]

# shapes
n = shape(x)[1]
p = shape(y)[1]

# colors and labels of the components
tab_colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:cyan']
tab_labels = ['$x_2$', '$x_3$', '$z_1$', '$z_2$', '$z_3$']

# plot the components
plot(t, x)
xlabel('System loops', size=20)
ylabel('Components of the system', size=20)
legend(tab_labels, loc=1, fontsize='xx-large')
title('Initial x', size=30)
# Out:
# Text(0.5, 1.0, 'Initial x')

# %%
# kalman parameters
H = delete(eye(n), [2,3,4], axis=0)
R = variance_obs_comp*eye(p)

# stochastic EM
x_s_V3, P_s_V3, M_V3, tab_loglik_V3, x = Kalman_SEM(x, y, H, R, nb_iter_SEM)
# Out:
# 100%|██████████| 30/30 [00:51<00:00,  1.70s/it]

# %%
# plot the reconstructed components
for i in range(n):
    plot(t, x_s_V3[:,i], color=tab_colors[i])
    fill_between(t, x_s_V3[:,i]-1.96*P_s_V3[:,i,i], x_s_V3[:,i]+1.96*P_s_V3[:,i,i],
                 facecolor=tab_colors[i], alpha=0.50)

xlabel('System loops', size=20)
ylabel('Components of the system', size=20)
legend(tab_labels, loc=1, fontsize='xx-large')
title('Final x', size=30)
# Out:
# Text(0.5, 1.0, 'Final x')

# %% [markdown]
# ### Results interpretation

# %%
# check the log-likelihoods
plot(tab_loglik_V1)
plot(tab_loglik_V2)
plot(tab_loglik_V3)
legend(['$x = [x_2, x_3, z_1]$', '$x = [x_2, x_3, z_1, z_2]$', '$x = [x_2, x_3, z_1, z_2, z_3]$'], loc=4, fontsize='xx-large')

# %%
# regression between x_s (from V2) and x_1
regress = LinearRegression(fit_intercept=False).fit(x_s_V2, x_t[:,0])
x_hat = regress.predict(x_s_V2)

# plot reconstructed x_1
plot(t, x_hat, color='tab:green')
plot(t, x_t[:,0], '--', color='tab:green')
legend(['$x_1$ (estimated)', '$x_1$ (truth)'], loc=4, fontsize='xx-large')

# print regression coefficients
print(regress.coef_)
# Out:
# [ 0.72153051  0.03745728  0.19916798 -0.09709696]

# %%
# write the ODEs (from V2)
print('V2 ODE coefficients:')
print(around((M_V2-eye(4))/dt, 1))
# Out:
# V2 ODE coefficients:
# [[  0.1  -0.1  -4.8   1.7]
#  [  0.9  -0.1   2.    8.2]
#  [ 12.5  -1.9 -20.4   2.2]
#  [ -1.7  -1.1   1.3 -15.9]]
